# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
file = '프로랜서tv.json'
data = None
with open(file, 'r') as f:
    data=json.load(f)

channel_id, stats = data.popitem()

print(channel_id)
# Out:
# UCeqArGCCdgsPxYaWndH_L-Q

# %%
video_stats = stats['video_data']

# %%
video_data = []
for vid in video_stats.items():
    video_id = vid[0]
    title = vid[1]['title']
    views = int(vid[1]['viewCount'])
    likes = int(vid[1]['likeCount'])
    dislikes = int(vid[1]['dislikeCount'])
    comments = int(vid[1]['commentCount'])
    release = vid[1]['publishedAt']
    video_data.append([title, views, likes, dislikes,comments, release])

# %%
video = pd.DataFrame(video_data, columns=['title','viewCount', 'likeCount', 'dislikeCount', 
                                          'commentCount', 'release'])
video['release'] = video['release'].apply(lambda x: x[:10])

# %%
video.set_index('title', inplace=True)

# %%
video.sort_values(by='viewCount', ascending=False)

video['release'] = pd.to_datetime(video['release'])

# %%
video.sort_values('viewCount', ascending=False)
# Out:
#                                                     viewCount  likeCount  \
# title
# 우드 잘치는법 ( 절대하면안되는 두가지 // 꼭지켜야할 세가지 )                   406385       3211
# 골프 스윙 힘빼는 방법 [ 장원주 프로의 12년 걸린 힘빼기 노하우 공개! ]            291638       3259
# 뒷땅 & 탑볼이 나는 이유 [ 이것만 조심하셔도 80%는 예방할 수 있어요!! ]          252028       3152
# [드라이버 비거리] 10분만에 20야드 증가 가능??                          140612       1687
# 뒷땅을 치는 이유 뒷땅 방지법 하루1분연습법                               132273       1615
# 야근보다 더 무서운 생크 치료받고 가세요!                                116391       1543
# 슬라이스 교정 슬라이스 방지법 이게 안바뀌면 절대 못 고칩니다!                     67709       1172
# [이쁜스윙] 프로처럼 이쁜스윙 당신도 할 수 있어요                            45340        639
# 다운스윙 ( 엎어치는 분들을 위한 두가지 솔루션! )                           31928        407
# 몸통스윙은 암스윙보다 안정적이고 일관성을 가질 수 있습니다.                       30922        541
# [골프회전] 올바른 골프 턴(회전) 체크하는 법, 골프 회전(턴) 할때 힘 주는 방법 공개      24874        478
# 주시를 모르면 절대로 에이밍을 똑바로 설 수 없습니다! ( 에이밍 & 얼라이먼트 //...      19684        311
# 치킨윙 스윙 [ 치킨윙 교정 알면 정말 쉬운 5분 연습법 ]                       19627        279
# (체중이동) 여러분들은 어쩌면 틀린 방법으로 체중이동을 하고 있을지 모릅니다              18893        285
# 숏아이언 하늘로 뜨기만 하고 거리 안나오시죠?                               18496        230
# 드로우 페이드 샷 // 드로우 페이드 치는법 // 드로우 페이드 원리                  16655        173
# 다운스윙 연습방법 다운스윙 파워업 다운스윙 팔내리기 다운스윙 전환동작                  15734        260
# 다운스윙 파워업! 체중이동! 비거리증가! 다운스윙 팔내리기 특급 연습 방법. #다운스윙        14727        225
# 백스윙요령! 테이크어웨이 치킨윙 오버스윙 self! 연습방법! #백스윙                 12899        226
# 그 어렵다는 스카이72 듄스코스 [ 오경환프로님 + 프로랜서 TV ]가 한번 조져 볼게요~      12007        226
# [ 몸통스윙 하니까 슬라이스 나는데요?? ]                                10320        157
# 드라이버 스윙 레슨 ( 4가지 요점 정리!!) 어프로치 샷 ( 3가지 요점 정리!!)          9632        216
# 싱글가려는 분들은 꼭 알아야할 (컨트롤샷&펀치샷)                              9602        200
# 5타 줄이는 필드 실전 퍼팅 레슨! [ 3명의 투어프로 연습방법 공개! ]                8661        142
# 어드레스 손위치 // 클럽별 공의 위치 // 클럽별 스탠스 무게중심 [ 구독자 오더 ...       8419        172
# 초보 골프 레슨 ( 리듬의 중요성과 손의 쓰임의 중요성을 두 프로가 레슨 했어요)            7518        167
# 스크린게임(홀당 꼴등은 채 하나씩 뻇기는 룰)                                6730         80
# 그린주변 어프로치 [ 띄우는샷//러닝샷 ]                                  5477        126
# [프로랜서TV]이벤트!! 9홀 대결로 무료레슨 해드립니다!                         5082        153
# 골프 스윙 손목 로테이션 손목의 올바른 쓰임                                 5065        150
# KPGA//KLPGA 투어 프로들의 연습방법 공개!!                            4854         73
# [필드 자투리레슨]  장원주 프로 회원권 판다구요???                           4716         98
# 초보 골프 레슨 (1명의 아마추어를 2명의 프로가 레슨했어요!!)                     4548         81
# 프로들이 공을 똑바로 칠 수 있는 이유 연습방법.                              4441        129
# 세이지우드 챌린지코스 9홀 3프로를 당황하게한 막강 아마추어의 출연!                   3230         37
# 초보 골프채 추천 (처음 시작하시는 초보분들과 풀세팅을 구성하시려는 입문자 분들을 구...       2955         34
# 백스윙요령 백스윙궤도 백스윙탑 ( 크로스오버 // 레이오프 고치는 연습방법 레슨!!)          2387         68
# 치킨윙 치킨윙교정 두가지 레슨!!                                       2157         91
# 스윙 스피드 올리기 1분 연습방법 스피드up! 비거리up!                         1775         71
# 세이지우드 전반9홀 롱기스트 니어핀 채두개로 홀인 재밌는 미니게임!                    1619         26
# 비거리 증가~! 골프 피트니스 (라운딩 전/후 부상방지 스트레칭)                     1511         51
# 어프로치 컨텍 1분연습방법 일단! 정확히 마추셔야 거리조절이 가능 합니다!                1139         42
#
#                                                     dislikeCount  \
# title
# 우드 잘치는법 ( 절대하면안되는 두가지 // 꼭지켜야할 세가지 )                         125
# 골프 스윙 힘빼는 방법 [ 장원주 프로의 12년 걸린 힘빼기 노하우 공개! ]                  121
# 뒷땅 & 탑볼이 나는 이유 [ 이것만 조심하셔도 80%는 예방할 수 있어요!! ]                111
# [드라이버 비거리] 10분만에 20야드 증가 가능??                                 73
# 뒷땅을 치는 이유 뒷땅 방지법 하루1분연습법                                      41
# 야근보다 더 무서운 생크 치료받고 가세요!                                       36
# 슬라이스 교정 슬라이스 방지법 이게 안바뀌면 절대 못 고칩니다!                           18
# [이쁜스윙] 프로처럼 이쁜스윙 당신도 할 수 있어요                                  20
# 다운스윙 ( 엎어치는 분들을 위한 두가지 솔루션! )                                  7
# 몸통스윙은 암스윙보다 안정적이고 일관성을 가질 수 있습니다.                             25
# [골프회전] 올바른 골프 턴(회전) 체크하는 법, 골프 회전(턴) 할때 힘 주는 방법 공개            10
# 주시를 모르면 절대로 에이밍을 똑바로 설 수 없습니다! ( 에이밍 & 얼라이먼트 //...             2
# 치킨윙 스윙 [ 치킨윙 교정 알면 정말 쉬운 5분 연습법 ]                              7
# (체중이동) 여러분들은 어쩌면 틀린 방법으로 체중이동을 하고 있을지 모릅니다                     7
# 숏아이언 하늘로 뜨기만 하고 거리 안나오시죠?                                      5
# 드로우 페이드 샷 // 드로우 페이드 치는법 // 드로우 페이드 원리                         6
# 다운스윙 연습방법 다운스윙 파워업 다운스윙 팔내리기 다운스윙 전환동작                         4
# 다운스윙 파워업! 체중이동! 비거리증가! 다운스윙 팔내리기 특급 연습 방법. #다운스윙               4
# 백스윙요령! 테이크어웨이 치킨윙 오버스윙 self! 연습방법! #백스윙                        5
# 그 어렵다는 스카이72 듄스코스 [ 오경환프로님 + 프로랜서 TV ]가 한번 조져 볼게요~             6
# [ 몸통스윙 하니까 슬라이스 나는데요?? ]                                       3
# 드라이버 스윙 레슨 ( 4가지 요점 정리!!) 어프로치 샷 ( 3가지 요점 정리!!)                2
# 싱글가려는 분들은 꼭 알아야할 (컨트롤샷&펀치샷)                                    7
# 5타 줄이는 필드 실전 퍼팅 레슨! [ 3명의 투어프로 연습방법 공개! ]                      2
# 어드레스 손위치 // 클럽별 공의 위치 // 클럽별 스탠스 무게중심 [ 구독자 오더 ...             3
# 초보 골프 레슨 ( 리듬의 중요성과 손의 쓰임의 중요성을 두 프로가 레슨 했어요)                  0
# 스크린게임(홀당 꼴등은 채 하나씩 뻇기는 룰)                                      2
# 그린주변 어프로치 [ 띄우는샷//러닝샷 ]                                        2
# [프로랜서TV]이벤트!! 9홀 대결로 무료레슨 해드립니다!                               3
# 골프 스윙 손목 로테이션 손목의 올바른 쓰임                                       3
# KPGA//KLPGA 투어 프로들의 연습방법 공개!!                                  1
# [필드 자투리레슨]  장원주 프로 회원권 판다구요???                                 1
# 초보 골프 레슨 (1명의 아마추어를 2명의 프로가 레슨했어요!!)                           0
# 프로들이 공을 똑바로 칠 수 있는 이유 연습방법.                                    2
# 세이지우드 챌린지코스 9홀 3프로를 당황하게한 막강 아마추어의 출연!                         3
# 초보 골프채 추천 (처음 시작하시는 초보분들과 풀세팅을 구성하시려는 입문자 분들을 구...             0
# 백스윙요령 백스윙궤도 백스윙탑 ( 크로스오버 // 레이오프 고치는 연습방법 레슨!!)                0
# 치킨윙 치킨윙교정 두가지 레슨!!                                             3
# 스윙 스피드 올리기 1분 연습방법 스피드up! 비거리up!                               1
# 세이지우드 전반9홀 롱기스트 니어핀 채두개로 홀인 재밌는 미니게임!                          0
# 비거리 증가~! 골프 피트니스 (라운딩 전/후 부상방지 스트레칭)                           0
# 어프로치 컨텍 1분연습방법 일단! 정확히 마추셔야 거리조절이 가능 합니다!                      0
#
#                                                     commentCount    release
# title
# 우드 잘치는법 ( 절대하면안되는 두가지 // 꼭지켜야할 세가지 )                          54 2020-05-14
# 골프 스윙 힘빼는 방법 [ 장원주 프로의 12년 걸린 힘빼기 노하우 공개! ]                   69 2020-04-23
# 뒷땅 & 탑볼이 나는 이유 [ 이것만 조심하셔도 80%는 예방할 수 있어요!! ]                136 2020-05-22
# [드라이버 비거리] 10분만에 20야드 증가 가능??                                 57 2020-07-02
# 뒷땅을 치는 이유 뒷땅 방지법 하루1분연습법                                      50 2020-02-02
# 야근보다 더 무서운 생크 치료받고 가세요!                                       77 2020-05-26
# 슬라이스 교정 슬라이스 방지법 이게 안바뀌면 절대 못 고칩니다!                           53 2020-01-26
# [이쁜스윙] 프로처럼 이쁜스윙 당신도 할 수 있어요                                  65 2020-07-06
# 다운스윙 ( 엎어치는 분들을 위한 두가지 솔루션! )                                 31 2020-06-07
# 몸통스윙은 암스윙보다 안정적이고 일관성을 가질 수 있습니다.                             40 2020-05-30
# [골프회전] 올바른 골프 턴(회전) 체크하는 법, 골프 회전(턴) 할때 힘 주는 방법 공개            51 2020-07-21
# 주시를 모르면 절대로 에이밍을 똑바로 설 수 없습니다! ( 에이밍 & 얼라이먼트 //...            21 2020-05-18
# 치킨윙 스윙 [ 치킨윙 교정 알면 정말 쉬운 5분 연습법 ]                             13 2020-04-08
# (체중이동) 여러분들은 어쩌면 틀린 방법으로 체중이동을 하고 있을지 모릅니다                     6 2020-06-28
# 숏아이언 하늘로 뜨기만 하고 거리 안나오시죠?                                     19 2020-06-11
# 드로우 페이드 샷 // 드로우 페이드 치는법 // 드로우 페이드 원리                        18 2020-03-10
# 다운스윙 연습방법 다운스윙 파워업 다운스윙 팔내리기 다운스윙 전환동작                        11 2020-01-18
# 다운스윙 파워업! 체중이동! 비거리증가! 다운스윙 팔내리기 특급 연습 방법. #다운스윙              14 2020-01-13
# 백스윙요령! 테이크어웨이 치킨윙 오버스윙 self! 연습방법! #백스윙                       23 2020-01-11
# 그 어렵다는 스카이72 듄스코스 [ 오경환프로님 + 프로랜서 TV ]가 한번 조져 볼게요~            21 2020-05-07
# [ 몸통스윙 하니까 슬라이스 나는데요?? ]                                      20 2020-07-26
# 드라이버 스윙 레슨 ( 4가지 요점 정리!!) 어프로치 샷 ( 3가지 요점 정리!!)               14 2020-04-01
# 싱글가려는 분들은 꼭 알아야할 (컨트롤샷&펀치샷)                                   22 2020-06-03
# 5타 줄이는 필드 실전 퍼팅 레슨! [ 3명의 투어프로 연습방법 공개! ]                     10 2020-04-12
# 어드레스 손위치 // 클럽별 공의 위치 // 클럽별 스탠스 무게중심 [ 구독자 오더 ...            19 2020-04-19
# 초보 골프 레슨 ( 리듬의 중요성과 손의 쓰임의 중요성을 두 프로가 레슨 했어요)                 42 2020-03-19
# 스크린게임(홀당 꼴등은 채 하나씩 뻇기는 룰)                                     21 2020-06-24
# 그린주변 어프로치 [ 띄우는샷//러닝샷 ]                                       18 2020-04-15
# [프로랜서TV]이벤트!! 9홀 대결로 무료레슨 해드립니다!                              29 2020-07-11
# 골프 스윙 손목 로테이션 손목의 올바른 쓰임                                      10 2020-02-16
# KPGA//KLPGA 투어 프로들의 연습방법 공개!!                                 17 2020-03-05
# [필드 자투리레슨]  장원주 프로 회원권 판다구요???                                28 2020-07-16
# 초보 골프 레슨 (1명의 아마추어를 2명의 프로가 레슨했어요!!)                          27 2020-03-24
# 프로들이 공을 똑바로 칠 수 있는 이유 연습방법.                                    7 2020-02-09
# 세이지우드 챌린지코스 9홀 3프로를 당황하게한 막강 아마추어의 출연!                        11 2020-06-15
# 초보 골프채 추천 (처음 시작하시는 초보분들과 풀세팅을 구성하시려는 입문자 분들을 구...            11 2020-03-16
# 백스윙요령 백스윙궤도 백스윙탑 ( 크로스오버 // 레이오프 고치는 연습방법 레슨!!)                5 2020-04-04
# 치킨윙 치킨윙교정 두가지 레슨!!                                            13 2020-02-13
# 스윙 스피드 올리기 1분 연습방법 스피드up! 비거리up!                              12 2020-02-20
# 세이지우드 전반9홀 롱기스트 니어핀 채두개로 홀인 재밌는 미니게임!                          4 2020-06-19
# 비거리 증가~! 골프 피트니스 (라운딩 전/후 부상방지 스트레칭)                           9 2020-05-03
# 어프로치 컨텍 1분연습방법 일단! 정확히 마추셔야 거리조절이 가능 합니다!                      7 2020-02-22

# %%
video['viewCount/day'] = video['viewCount'] / ((pd.to_datetime('today') - video['release']).dt.days)
video['viewCount/day'] = video['viewCount/day'].astype('int')

# %%
video.sort_values('viewCount/day', ascending=False)
# Out:
#                                                     viewCount  likeCount  \
# title
# 우드 잘치는법 ( 절대하면안되는 두가지 // 꼭지켜야할 세가지 )                   406385       3211
# [드라이버 비거리] 10분만에 20야드 증가 가능??                          140612       1687
# 뒷땅 & 탑볼이 나는 이유 [ 이것만 조심하셔도 80%는 예방할 수 있어요!! ]          252028       3152
# [ 몸통스윙 하니까 슬라이스 나는데요?? ]                                10320        157
# [골프회전] 올바른 골프 턴(회전) 체크하는 법, 골프 회전(턴) 할때 힘 주는 방법 공개      24874        478
# 골프 스윙 힘빼는 방법 [ 장원주 프로의 12년 걸린 힘빼기 노하우 공개! ]            291638       3259
# [이쁜스윙] 프로처럼 이쁜스윙 당신도 할 수 있어요                            45340        639
# 야근보다 더 무서운 생크 치료받고 가세요!                                116391       1543
# 뒷땅을 치는 이유 뒷땅 방지법 하루1분연습법                               132273       1615
# 다운스윙 ( 엎어치는 분들을 위한 두가지 솔루션! )                           31928        407
# (체중이동) 여러분들은 어쩌면 틀린 방법으로 체중이동을 하고 있을지 모릅니다              18893        285
# 몸통스윙은 암스윙보다 안정적이고 일관성을 가질 수 있습니다.                       30922        541
# 숏아이언 하늘로 뜨기만 하고 거리 안나오시죠?                               18496        230
# 슬라이스 교정 슬라이스 방지법 이게 안바뀌면 절대 못 고칩니다!                     67709       1172
# [필드 자투리레슨]  장원주 프로 회원권 판다구요???                           4716         98
# [프로랜서TV]이벤트!! 9홀 대결로 무료레슨 해드립니다!                         5082        153
# 주시를 모르면 절대로 에이밍을 똑바로 설 수 없습니다! ( 에이밍 & 얼라이먼트 //...      19684        311
# 스크린게임(홀당 꼴등은 채 하나씩 뻇기는 룰)                                6730         80
# 치킨윙 스윙 [ 치킨윙 교정 알면 정말 쉬운 5분 연습법 ]                       19627        279
# 싱글가려는 분들은 꼭 알아야할 (컨트롤샷&펀치샷)                              9602        200
# 그 어렵다는 스카이72 듄스코스 [ 오경환프로님 + 프로랜서 TV ]가 한번 조져 볼게요~      12007        226
# 드로우 페이드 샷 // 드로우 페이드 치는법 // 드로우 페이드 원리                  16655        173
# 어드레스 손위치 // 클럽별 공의 위치 // 클럽별 스탠스 무게중심 [ 구독자 오더 ...       8419        172
# 다운스윙 연습방법 다운스윙 파워업 다운스윙 팔내리기 다운스윙 전환동작                  15734        260
# 5타 줄이는 필드 실전 퍼팅 레슨! [ 3명의 투어프로 연습방법 공개! ]                8661        142
# 드라이버 스윙 레슨 ( 4가지 요점 정리!!) 어프로치 샷 ( 3가지 요점 정리!!)          9632        216
# 다운스윙 파워업! 체중이동! 비거리증가! 다운스윙 팔내리기 특급 연습 방법. #다운스윙        14727        225
# 세이지우드 챌린지코스 9홀 3프로를 당황하게한 막강 아마추어의 출연!                   3230         37
# 백스윙요령! 테이크어웨이 치킨윙 오버스윙 self! 연습방법! #백스윙                 12899        226
# 초보 골프 레슨 ( 리듬의 중요성과 손의 쓰임의 중요성을 두 프로가 레슨 했어요)            7518        167
# 그린주변 어프로치 [ 띄우는샷//러닝샷 ]                                  5477        126
# 세이지우드 전반9홀 롱기스트 니어핀 채두개로 홀인 재밌는 미니게임!                    1619         26
# 초보 골프 레슨 (1명의 아마추어를 2명의 프로가 레슨했어요!!)                     4548         81
# KPGA//KLPGA 투어 프로들의 연습방법 공개!!                            4854         73
# 골프 스윙 손목 로테이션 손목의 올바른 쓰임                                 5065        150
# 프로들이 공을 똑바로 칠 수 있는 이유 연습방법.                              4441        129
# 초보 골프채 추천 (처음 시작하시는 초보분들과 풀세팅을 구성하시려는 입문자 분들을 구...       2955         34
# 백스윙요령 백스윙궤도 백스윙탑 ( 크로스오버 // 레이오프 고치는 연습방법 레슨!!)          2387         68
# 비거리 증가~! 골프 피트니스 (라운딩 전/후 부상방지 스트레칭)                     1511         51
# 치킨윙 치킨윙교정 두가지 레슨!!                                       2157         91
# 스윙 스피드 올리기 1분 연습방법 스피드up! 비거리up!                         1775         71
# 어프로치 컨텍 1분연습방법 일단! 정확히 마추셔야 거리조절이 가능 합니다!                1139         42
#
#                                                     dislikeCount  \
# title
# 우드 잘치는법 ( 절대하면안되는 두가지 // 꼭지켜야할 세가지 )                         125
# [드라이버 비거리] 10분만에 20야드 증가 가능??                                 73
# 뒷땅 & 탑볼이 나는 이유 [ 이것만 조심하셔도 80%는 예방할 수 있어요!! ]                111
# [ 몸통스윙 하니까 슬라이스 나는데요?? ]                                       3
# [골프회전] 올바른 골프 턴(회전) 체크하는 법, 골프 회전(턴) 할때 힘 주는 방법 공개            10
# 골프 스윙 힘빼는 방법 [ 장원주 프로의 12년 걸린 힘빼기 노하우 공개! ]                  121
# [이쁜스윙] 프로처럼 이쁜스윙 당신도 할 수 있어요                                  20
# 야근보다 더 무서운 생크 치료받고 가세요!                                       36
# 뒷땅을 치는 이유 뒷땅 방지법 하루1분연습법                                      41
# 다운스윙 ( 엎어치는 분들을 위한 두가지 솔루션! )                                  7
# (체중이동) 여러분들은 어쩌면 틀린 방법으로 체중이동을 하고 있을지 모릅니다                     7
# 몸통스윙은 암스윙보다 안정적이고 일관성을 가질 수 있습니다.                             25
# 숏아이언 하늘로 뜨기만 하고 거리 안나오시죠?                                      5
# 슬라이스 교정 슬라이스 방지법 이게 안바뀌면 절대 못 고칩니다!                           18
# [필드 자투리레슨]  장원주 프로 회원권 판다구요???                                 1
# [프로랜서TV]이벤트!! 9홀 대결로 무료레슨 해드립니다!                               3
# 주시를 모르면 절대로 에이밍을 똑바로 설 수 없습니다! ( 에이밍 & 얼라이먼트 //...             2
# 스크린게임(홀당 꼴등은 채 하나씩 뻇기는 룰)                                      2
# 치킨윙 스윙 [ 치킨윙 교정 알면 정말 쉬운 5분 연습법 ]                              7
# 싱글가려는 분들은 꼭 알아야할 (컨트롤샷&펀치샷)                                    7
# 그 어렵다는 스카이72 듄스코스 [ 오경환프로님 + 프로랜서 TV ]가 한번 조져 볼게요~             6
# 드로우 페이드 샷 // 드로우 페이드 치는법 // 드로우 페이드 원리                         6
# 어드레스 손위치 // 클럽별 공의 위치 // 클럽별 스탠스 무게중심 [ 구독자 오더 ...             3
# 다운스윙 연습방법 다운스윙 파워업 다운스윙 팔내리기 다운스윙 전환동작                         4
# 5타 줄이는 필드 실전 퍼팅 레슨! [ 3명의 투어프로 연습방법 공개! ]                      2
# 드라이버 스윙 레슨 ( 4가지 요점 정리!!) 어프로치 샷 ( 3가지 요점 정리!!)                2
# 다운스윙 파워업! 체중이동! 비거리증가! 다운스윙 팔내리기 특급 연습 방법. #다운스윙               4
# 세이지우드 챌린지코스 9홀 3프로를 당황하게한 막강 아마추어의 출연!                         3
# 백스윙요령! 테이크어웨이 치킨윙 오버스윙 self! 연습방법! #백스윙                        5
# 초보 골프 레슨 ( 리듬의 중요성과 손의 쓰임의 중요성을 두 프로가 레슨 했어요)                  0
# 그린주변 어프로치 [ 띄우는샷//러닝샷 ]                                        2
# 세이지우드 전반9홀 롱기스트 니어핀 채두개로 홀인 재밌는 미니게임!                          0
# 초보 골프 레슨 (1명의 아마추어를 2명의 프로가 레슨했어요!!)                           0
# KPGA//KLPGA 투어 프로들의 연습방법 공개!!                                  1
# 골프 스윙 손목 로테이션 손목의 올바른 쓰임                                       3
# 프로들이 공을 똑바로 칠 수 있는 이유 연습방법.                                    2
# 초보 골프채 추천 (처음 시작하시는 초보분들과 풀세팅을 구성하시려는 입문자 분들을 구...             0
# 백스윙요령 백스윙궤도 백스윙탑 ( 크로스오버 // 레이오프 고치는 연습방법 레슨!!)                0
# 비거리 증가~! 골프 피트니스 (라운딩 전/후 부상방지 스트레칭)                           0
# 치킨윙 치킨윙교정 두가지 레슨!!                                             3
# 스윙 스피드 올리기 1분 연습방법 스피드up! 비거리up!                               1
# 어프로치 컨텍 1분연습방법 일단! 정확히 마추셔야 거리조절이 가능 합니다!                      0
#
#                                                     commentCount    release  \
# title
# 우드 잘치는법 ( 절대하면안되는 두가지 // 꼭지켜야할 세가지 )                          54 2020-05-14
# [드라이버 비거리] 10분만에 20야드 증가 가능??                                 57 2020-07-02
# 뒷땅 & 탑볼이 나는 이유 [ 이것만 조심하셔도 80%는 예방할 수 있어요!! ]                136 2020-05-22
# [ 몸통스윙 하니까 슬라이스 나는데요?? ]                                      20 2020-07-26
# [골프회전] 올바른 골프 턴(회전) 체크하는 법, 골프 회전(턴) 할때 힘 주는 방법 공개            51 2020-07-21
# 골프 스윙 힘빼는 방법 [ 장원주 프로의 12년 걸린 힘빼기 노하우 공개! ]                   69 2020-04-23
# [이쁜스윙] 프로처럼 이쁜스윙 당신도 할 수 있어요                                  65 2020-07-06
# 야근보다 더 무서운 생크 치료받고 가세요!                                       77 2020-05-26
# 뒷땅을 치는 이유 뒷땅 방지법 하루1분연습법                                      50 2020-02-02
# 다운스윙 ( 엎어치는 분들을 위한 두가지 솔루션! )                                 31 2020-06-07
# (체중이동) 여러분들은 어쩌면 틀린 방법으로 체중이동을 하고 있을지 모릅니다                     6 2020-06-28
# 몸통스윙은 암스윙보다 안정적이고 일관성을 가질 수 있습니다.                             40 2020-05-30
# 숏아이언 하늘로 뜨기만 하고 거리 안나오시죠?                                     19 2020-06-11
# 슬라이스 교정 슬라이스 방지법 이게 안바뀌면 절대 못 고칩니다!                           53 2020-01-26
# [필드 자투리레슨]  장원주 프로 회원권 판다구요???                                28 2020-07-16
# [프로랜서TV]이벤트!! 9홀 대결로 무료레슨 해드립니다!                              29 2020-07-11
# 주시를 모르면 절대로 에이밍을 똑바로 설 수 없습니다! ( 에이밍 & 얼라이먼트 //...            21 2020-05-18
# 스크린게임(홀당 꼴등은 채 하나씩 뻇기는 룰)                                     21 2020-06-24
# 치킨윙 스윙 [ 치킨윙 교정 알면 정말 쉬운 5분 연습법 ]                             13 2020-04-08
# 싱글가려는 분들은 꼭 알아야할 (컨트롤샷&펀치샷)                                   22 2020-06-03
# 그 어렵다는 스카이72 듄스코스 [ 오경환프로님 + 프로랜서 TV ]가 한번 조져 볼게요~            21 2020-05-07
# 드로우 페이드 샷 // 드로우 페이드 치는법 // 드로우 페이드 원리                        18 2020-03-10
# 어드레스 손위치 // 클럽별 공의 위치 // 클럽별 스탠스 무게중심 [ 구독자 오더 ...            19 2020-04-19
# 다운스윙 연습방법 다운스윙 파워업 다운스윙 팔내리기 다운스윙 전환동작                        11 2020-01-18
# 5타 줄이는 필드 실전 퍼팅 레슨! [ 3명의 투어프로 연습방법 공개! ]                     10 2020-04-12
# 드라이버 스윙 레슨 ( 4가지 요점 정리!!) 어프로치 샷 ( 3가지 요점 정리!!)               14 2020-04-01
# 다운스윙 파워업! 체중이동! 비거리증가! 다운스윙 팔내리기 특급 연습 방법. #다운스윙              14 2020-01-13
# 세이지우드 챌린지코스 9홀 3프로를 당황하게한 막강 아마추어의 출연!                        11 2020-06-15
# 백스윙요령! 테이크어웨이 치킨윙 오버스윙 self! 연습방법! #백스윙                       23 2020-01-11
# 초보 골프 레슨 ( 리듬의 중요성과 손의 쓰임의 중요성을 두 프로가 레슨 했어요)                 42 2020-03-19
# 그린주변 어프로치 [ 띄우는샷//러닝샷 ]                                       18 2020-04-15
# 세이지우드 전반9홀 롱기스트 니어핀 채두개로 홀인 재밌는 미니게임!                          4 2020-06-19
# 초보 골프 레슨 (1명의 아마추어를 2명의 프로가 레슨했어요!!)                          27 2020-03-24
# KPGA//KLPGA 투어 프로들의 연습방법 공개!!                                 17 2020-03-05
# 골프 스윙 손목 로테이션 손목의 올바른 쓰임                                      10 2020-02-16
# 프로들이 공을 똑바로 칠 수 있는 이유 연습방법.                                    7 2020-02-09
# 초보 골프채 추천 (처음 시작하시는 초보분들과 풀세팅을 구성하시려는 입문자 분들을 구...            11 2020-03-16
# 백스윙요령 백스윙궤도 백스윙탑 ( 크로스오버 // 레이오프 고치는 연습방법 레슨!!)                5 2020-04-04
# 비거리 증가~! 골프 피트니스 (라운딩 전/후 부상방지 스트레칭)                           9 2020-05-03
# 치킨윙 치킨윙교정 두가지 레슨!!                                            13 2020-02-13
# 스윙 스피드 올리기 1분 연습방법 스피드up! 비거리up!                              12 2020-02-20
# 어프로치 컨텍 1분연습방법 일단! 정확히 마추셔야 거리조절이 가능 합니다!                      7 2020-02-22
#
#                                                     viewCount/day
# title
# 우드 잘치는법 ( 절대하면안되는 두가지 // 꼭지켜야할 세가지 )                         5347
# [드라이버 비거리] 10분만에 20야드 증가 가능??                                5207
# 뒷땅 & 탑볼이 나는 이유 [ 이것만 조심하셔도 80%는 예방할 수 있어요!! ]                3706
# [ 몸통스윙 하니까 슬라이스 나는데요?? ]                                     3440
# [골프회전] 올바른 골프 턴(회전) 체크하는 법, 골프 회전(턴) 할때 힘 주는 방법 공개           3109
# 골프 스윙 힘빼는 방법 [ 장원주 프로의 12년 걸린 힘빼기 노하우 공개! ]                  3006
# [이쁜스윙] 프로처럼 이쁜스윙 당신도 할 수 있어요                                 1971
# 야근보다 더 무서운 생크 치료받고 가세요!                                      1818
# 뒷땅을 치는 이유 뒷땅 방지법 하루1분연습법                                      743
# 다운스윙 ( 엎어치는 분들을 위한 두가지 솔루션! )                                 614
# (체중이동) 여러분들은 어쩌면 틀린 방법으로 체중이동을 하고 있을지 모릅니다                    609
# 몸통스윙은 암스윙보다 안정적이고 일관성을 가질 수 있습니다.                             515
# 숏아이언 하늘로 뜨기만 하고 거리 안나오시죠?                                     385
# 슬라이스 교정 슬라이스 방지법 이게 안바뀌면 절대 못 고칩니다!                           365
# [필드 자투리레슨]  장원주 프로 회원권 판다구요???                                362
# [프로랜서TV]이벤트!! 9홀 대결로 무료레슨 해드립니다!                              282
# 주시를 모르면 절대로 에이밍을 똑바로 설 수 없습니다! ( 에이밍 & 얼라이먼트 //...            273
# 스크린게임(홀당 꼴등은 채 하나씩 뻇기는 룰)                                     192
# 치킨윙 스윙 [ 치킨윙 교정 알면 정말 쉬운 5분 연습법 ]                             175
# 싱글가려는 분들은 꼭 알아야할 (컨트롤샷&펀치샷)                                   171
# 그 어렵다는 스카이72 듄스코스 [ 오경환프로님 + 프로랜서 TV ]가 한번 조져 볼게요~            144
# 드로우 페이드 샷 // 드로우 페이드 치는법 // 드로우 페이드 원리                        118
# 어드레스 손위치 // 클럽별 공의 위치 // 클럽별 스탠스 무게중심 [ 구독자 오더 ...             83
# 다운스윙 연습방법 다운스윙 파워업 다운스윙 팔내리기 다운스윙 전환동작                         81
# 5타 줄이는 필드 실전 퍼팅 레슨! [ 3명의 투어프로 연습방법 공개! ]                      80
# 드라이버 스윙 레슨 ( 4가지 요점 정리!!) 어프로치 샷 ( 3가지 요점 정리!!)                80
# 다운스윙 파워업! 체중이동! 비거리증가! 다운스윙 팔내리기 특급 연습 방법. #다운스윙               74
# 세이지우드 챌린지코스 9홀 3프로를 당황하게한 막강 아마추어의 출연!                         73
# 백스윙요령! 테이크어웨이 치킨윙 오버스윙 self! 연습방법! #백스윙                        64
# 초보 골프 레슨 ( 리듬의 중요성과 손의 쓰임의 중요성을 두 프로가 레슨 했어요)                  56
# 그린주변 어프로치 [ 띄우는샷//러닝샷 ]                                        52
# 세이지우드 전반9홀 롱기스트 니어핀 채두개로 홀인 재밌는 미니게임!                          40
# 초보 골프 레슨 (1명의 아마추어를 2명의 프로가 레슨했어요!!)                           35
# KPGA//KLPGA 투어 프로들의 연습방법 공개!!                                  33
# 골프 스윙 손목 로테이션 손목의 올바른 쓰임                                       30
# 프로들이 공을 똑바로 칠 수 있는 이유 연습방법.                                    25
# 초보 골프채 추천 (처음 시작하시는 초보분들과 풀세팅을 구성하시려는 입문자 분들을 구...             21
# 백스윙요령 백스윙궤도 백스윙탑 ( 크로스오버 // 레이오프 고치는 연습방법 레슨!!)                20
# 비거리 증가~! 골프 피트니스 (라운딩 전/후 부상방지 스트레칭)                           17
# 치킨윙 치킨윙교정 두가지 레슨!!                                             12
# 스윙 스피드 올리기 1분 연습방법 스피드up! 비거리up!                               11
# 어프로치 컨텍 1분연습방법 일단! 정확히 마추셔야 거리조절이 가능 합니다!                       7
